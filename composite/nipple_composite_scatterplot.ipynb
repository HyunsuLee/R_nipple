# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
comp = pd.read_csv('composite.csv')

# %%
comp.head()
# Out:
#   Gene_name                            Gene_description  \
# 0      Zzz3         zinc finger, ZZ domain containing 3
# 1     Zzef1  zinc finger, ZZ-type with EF hand domain 1
# 2       Zyx                                       zyxin
# 3    Zyg11b               zyg-ll homolog B (C. elegans)
# 4    Zyg11a               zyg-11 homolog A (C. elegans)
#
#    Stromal vehicle replicate 1  Stromal vehicle replicate 2  \
# 0                     0.040107                     0.022851
# 1                     1.682737                     1.458661
# 2                     0.703758                     0.491210
# 3                     1.456132                    -0.756914
# 4                     0.286801                     0.313138
#
#    Stromal vehicle replicate 3  Stromal estrogen replicate 1  \
# 0                     0.050366                      0.062459
# 1                     0.975409                      1.600930
# 2                     0.513616                      0.823215
# ...

# %%
comp_sub = comp.iloc[:, 3:14]

# %%
comp_sub.head()
# Out:
#    Stromal vehicle replicate 2  Stromal vehicle replicate 3  \
# 0                     0.022851                     0.050366
# 1                     1.458661                     0.975409
# 2                     0.491210                     0.513616
# 3                    -0.756914                    -0.811344
# 4                     0.313138                     0.283574
#
#    Stromal estrogen replicate 1  Stromal estrogen replicate 2  \
# 0                      0.062459                      0.492240
# 1                      1.600930                      1.481236
# 2                      0.823215                      0.955584
# 3                      1.367426                     -0.176763
# 4                      0.222738                      0.098604
#
#    Stromal estrogen replicate 3  \
# 0                      0.678702
# 1                      1.728604
# 2                      0.955960
# 3                      0.938451
# 4                      0.259777
#
# ...

# %%
scatter = pd.tools.plotting.scatter_matrix(comp_sub, alpha=0.2, figsize = (32,32), diagonal = 'kde')
scatter.plt.savefig('scatter_matrix_t.jpg')

# %%
plt.close()

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import csv

# %%
comp = pd.read_csv('composite.csv')

# %%
comp.head
# Out:
# <bound method DataFrame.head of            Gene_name                                   Gene_description  \
# 0               Zzz3                zinc finger, ZZ domain containing 3
# 1              Zzef1         zinc finger, ZZ-type with EF hand domain 1
# 2                Zyx                                              zyxin
# 3             Zyg11b                      zyg-ll homolog B (C. elegans)
# 4             Zyg11a                      zyg-11 homolog A (C. elegans)
# 5               Zxdc                           ZXD family zinc finger C
# 6               Zxdb                zinc finger, X-linked, duplicated B
# 7               Zxda                zinc finger, X-linked, duplicated A
# 8              Zwint                                    ZW10 interactor
# 9             Zwilch  Zwilch, kinetochore associated, homolog (Droso...
# 10              Zw10  ZW10 homolog (Drosophila), centromere/kinetoch...
# 11             Zufsp    zinc finger with UFM1-specific peptidase domain
# ...

# %%
comp.head()
# Out:
#   Gene_name                            Gene_description  \
# 0      Zzz3         zinc finger, ZZ domain containing 3
# 1     Zzef1  zinc finger, ZZ-type with EF hand domain 1
# 2       Zyx                                       zyxin
# 3    Zyg11b               zyg-ll homolog B (C. elegans)
# 4    Zyg11a               zyg-11 homolog A (C. elegans)
#
#    Stromal vehicle replicate 1  Stromal vehicle replicate 2  \
# 0                     0.040107                     0.022851
# 1                     1.682737                     1.458661
# 2                     0.703758                     0.491210
# 3                     1.456132                    -0.756914
# 4                     0.286801                     0.313138
#
#    Stromal vehicle replicate 3  Stromal estrogen replicate 1  \
# 0                     0.050366                      0.062459
# 1                     0.975409                      1.600930
# 2                     0.513616                      0.823215
# ...

# %%
comp[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-94cff06d617c> in <module>()
# ----> 1 comp[1]
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
# ...

# %%
comp(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-112151340f03> in <module>()
# ----> 1 comp(1)
#
# TypeError: 'DataFrame' object is not callable

# %%
comp["Gene_name"].head()
# Out:
# 0      Zzz3
# 1     Zzef1
# 2       Zyx
# 3    Zyg11b
# 4    Zyg11a
# Name: Gene_name, dtype: object

# %%
# ?pd

# %%
comp_df = pd.DataFrame(comp)

# %%
comp_df
# Out:
#            Gene_name                                   Gene_description  \
# 0               Zzz3                zinc finger, ZZ domain containing 3
# 1              Zzef1         zinc finger, ZZ-type with EF hand domain 1
# 2                Zyx                                              zyxin
# 3             Zyg11b                      zyg-ll homolog B (C. elegans)
# 4             Zyg11a                      zyg-11 homolog A (C. elegans)
# 5               Zxdc                           ZXD family zinc finger C
# 6               Zxdb                zinc finger, X-linked, duplicated B
# 7               Zxda                zinc finger, X-linked, duplicated A
# 8              Zwint                                    ZW10 interactor
# 9             Zwilch  Zwilch, kinetochore associated, homolog (Droso...
# 10              Zw10  ZW10 homolog (Drosophila), centromere/kinetoch...
# 11             Zufsp    zinc finger with UFM1-specific peptidase domain
# ...

# %%
comp
# Out:
#            Gene_name                                   Gene_description  \
# 0               Zzz3                zinc finger, ZZ domain containing 3
# 1              Zzef1         zinc finger, ZZ-type with EF hand domain 1
# 2                Zyx                                              zyxin
# 3             Zyg11b                      zyg-ll homolog B (C. elegans)
# 4             Zyg11a                      zyg-11 homolog A (C. elegans)
# 5               Zxdc                           ZXD family zinc finger C
# 6               Zxdb                zinc finger, X-linked, duplicated B
# 7               Zxda                zinc finger, X-linked, duplicated A
# 8              Zwint                                    ZW10 interactor
# 9             Zwilch  Zwilch, kinetochore associated, homolog (Droso...
# 10              Zw10  ZW10 homolog (Drosophila), centromere/kinetoch...
# 11             Zufsp    zinc finger with UFM1-specific peptidase domain
# ...

# %%
comp.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-e66679e716ef> in <module>()
# ----> 1 comp.a
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'a'

# %%
comp_df = pd.DataFrame(comp, columns = list(range(1,14,1)))

# %%
comp
# Out:
#            Gene_name                                   Gene_description  \
# 0               Zzz3                zinc finger, ZZ domain containing 3
# 1              Zzef1         zinc finger, ZZ-type with EF hand domain 1
# 2                Zyx                                              zyxin
# 3             Zyg11b                      zyg-ll homolog B (C. elegans)
# 4             Zyg11a                      zyg-11 homolog A (C. elegans)
# 5               Zxdc                           ZXD family zinc finger C
# 6               Zxdb                zinc finger, X-linked, duplicated B
# 7               Zxda                zinc finger, X-linked, duplicated A
# 8              Zwint                                    ZW10 interactor
# 9             Zwilch  Zwilch, kinetochore associated, homolog (Droso...
# 10              Zw10  ZW10 homolog (Drosophila), centromere/kinetoch...
# 11             Zufsp    zinc finger with UFM1-specific peptidase domain
# ...

# %%
comp.iloc[:, 1:3]
# Out:
#                                         Gene_description  \
# 0                    zinc finger, ZZ domain containing 3
# 1             zinc finger, ZZ-type with EF hand domain 1
# 2                                                  zyxin
# 3                          zyg-ll homolog B (C. elegans)
# 4                          zyg-11 homolog A (C. elegans)
# 5                               ZXD family zinc finger C
# 6                    zinc finger, X-linked, duplicated B
# 7                    zinc finger, X-linked, duplicated A
# 8                                        ZW10 interactor
# 9      Zwilch, kinetochore associated, homolog (Droso...
# 10     ZW10 homolog (Drosophila), centromere/kinetoch...
# 11       zinc finger with UFM1-specific peptidase domain
# 12                   zinc finger, SWIM-type containing 7
# 13                 zinc finger, SWIM domain containing 6
# 14                 zinc finger, SWIM domain containing 5
# ...

# %%
comp_sub = comp.iloc[:, 3:14]

# %%
comp_sub
# Out:
#        Stromal vehicle replicate 2  Stromal vehicle replicate 3  \
# 0                         0.022851                     0.050366
# 1                         1.458661                     0.975409
# 2                         0.491210                     0.513616
# 3                        -0.756914                    -0.811344
# 4                         0.313138                     0.283574
# 5                         3.368397                     3.109381
# 6                         0.351344                     0.936789
# 7                         0.139485                     0.287230
# 8                         2.072805                     2.096588
# 9                        -1.879881                    -2.254541
# 10                        1.865070                     1.572489
# 11                        1.605841                     1.294478
# 12                       -1.198914                    -1.982389
# 13                        3.110417                     2.803817
# ...

# %%
comp_sub.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x129c03f10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a684550>]], dtype=object)

# %%
plt.savefig('scatter_matrix.png')

# %%
pd.tools.plotting.scatter_matrix(comp_sub, alpha=0.2, figsize = (32,32), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1626ba250>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x16a097b90>]], dtype=object)

# %%
plt.savefig('scatter_matrix.jpg')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-0db8fca91b59> in <module>()
# ----> 1 plt.savefig('scatter_matrix.jpg')
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in savefig(*args, **kwargs)
#     575 def savefig(*args, **kwargs):
#     576     fig = gcf()
# --> 577     res = fig.savefig(*args, **kwargs)
#     578     draw()   # need this if 'transparent=True' to reset colors
#     579     return res
#
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, *args, **kwargs)
#    1474             self.set_frameon(frameon)
#    1475
# -> 1476         self.canvas.print_figure(*args, **kwargs)
#    1477
#    1478         if frameon:
#
# ...

# %%
plt.close()

# %%
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-62-ed9806ce3570> in <module>()
# ----> 1 import seaborn as sns
#
# ImportError: No module named seaborn

# %%
pd.tools.plotting.scatter_matrix(comp)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11848d9d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1208535d0>]], dtype=object)

# %%
comp.head
# Out:
# <bound method DataFrame.head of                 Zzz3                zinc finger, ZZ domain containing 3  \
# 0              Zzef1         zinc finger, ZZ-type with EF hand domain 1
# 1                Zyx                                              zyxin
# 2             Zyg11b                      zyg-ll homolog B (C. elegans)
# 3             Zyg11a                      zyg-11 homolog A (C. elegans)
# 4               Zxdc                           ZXD family zinc finger C
# 5               Zxdb                zinc finger, X-linked, duplicated B
# 6               Zxda                zinc finger, X-linked, duplicated A
# 7              Zwint                                    ZW10 interactor
# 8             Zwilch  Zwilch, kinetochore associated, homolog (Droso...
# 9               Zw10  ZW10 homolog (Drosophila), centromere/kinetoch...
# 10             Zufsp    zinc finger with UFM1-specific peptidase domain
# 11            Zswim7                zinc finger, SWIM-type containing 7
# ...

# %%
comp = pd.read_scv('composite.csv', header=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-b9799aec6373> in <module>()
# ----> 1 comp = pd.read_scv('composite.csv', header=True)
#
# AttributeError: 'module' object has no attribute 'read_scv'
